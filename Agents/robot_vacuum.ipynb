# %% [markdown]
# # Intelligent Agents: Reflex-Based Agents for the Vacuum-cleaner World
#
# Student Name: [Add your name]
#
# I have used the following AI tools: [list tools]
#
# I understand that my submission needs to be my own work: [your initials]

# %% [markdown]
# ## Learning Outcomes
#
# * Design and build a simulation environment that models sensor inputs, actuator effects, and performance measurement.
# * Apply core AI concepts by implementing the agent function for a simple and model-based reflex agents that respond to environmental percepts.
# * Practice how the environment and the agent function interact.
# * Analyze agent performance through controlled experiments across different environment configurations.
# * Graduate Students: Develop strategies for handling uncertainty and imperfect information in autonomous agent systems.
#
# ## Instructions
#
# Total Points: Undergrads 100 + 5 bonus / Graduate students 110
#
# Complete this notebook. Use the provided notebook cells and insert additional code and markdown cells as needed. Submit the completely rendered notebook as a HTML file.
#
# ### AI Use
#
# Here are some guidelines that will make it easier for you:
#
# * __Don't:__ Rely on AI auto completion. You will waste a lot of time trying to figure out how the suggested code relates to what we do in class. Turn off AI code completion (e.g., Copilot) in your IDE.
# * __Don't:__ Do not submit code/text that you do not understand or have not checked to make sure that it is complete and correct.
# * __Do:__ Use AI for debugging and letting it explain code and concepts from class.
#
# ### Using Visual Studio Code
#
# If you use VS code then you can use `Export` (click on `...` in the menu bar) to save your notebook as a HTML file. Note that you have to run all blocks before so the HTML file contains your output.
#
# ### Using Google Colab
#
# In Colab you need to save the notebook on GoogleDrive to work with it. For this you need to mount your google dive and change to the correct directory by uncommenting the following lines and running the code block.

# %%
# from google.colab import drive
# import os
#
# drive.mount('/content/drive')
# os.chdir('/content/drive/My Drive/Colab Notebooks/')

# %% [markdown]
# Once you are done with the assignment and have run all code blocks using `Runtime/Run all`, you can convert the file on your GoogleDrive into HTML be uncommenting the following line and running the block.

# %%
# !jupyter nbconvert --to html Copy\ of\ robot_vacuum.ipynb

# %% [markdown]
# You may have to fix the file location or the file name to match how it looks on your GoogleDrive. You can navigate in Colab to your GoogleDrive using the little folder symbol in the navigation bar to the left.

# %% [markdown]
# ## Introduction
#
# In this assignment you will implement a simulator environment for an automatic vacuum cleaner robot, a set of different reflex-based agent programs, and perform a comparison study for cleaning a single room. Focus on the __cleaning phase__ which starts when the robot is activated and ends when the last dirty square in the room has been cleaned. Someone else will take care of the agent program needed to navigate back to the charging station after the room is clean.
#
# ## PEAS description of the cleaning phase
#
# __Performance Measure:__ Each action costs 1 energy unit. The performance is measured as the sum of the energy units used to clean the whole room.
#
# __Environment:__ A room with $n \times n$ squares where $n = 5$. Dirt is randomly placed on each square with probability $p = 0.2$. For simplicity, you can assume that the agent knows the size and the layout of the room (i.e., it knows $n$). To start, the agent is placed on a random square.
#
# __Actuators:__ The agent can clean the current square (action `suck`) or move to an adjacent square by going `north`, `east`, `south`, or `west`.
#
# __Sensors:__ Four bumper sensors, one for north, east, south, and west; a dirt sensor reporting dirt in the current square.
#
#
# ## The agent program for a simple randomized agent
#
# The agent program is a function that gets sensor information (the current percepts) as the arguments. The arguments are:
#
# * A dictionary with boolean entries for the for bumper sensors `north`, `east`, `west`, `south`. E.g., if the agent is on the north-west corner, `bumpers` will be `{"north" : True, "east" : False, "south" : False, "west" : True}`.
# * The dirt sensor produces a boolean.
#
# The agent returns the chosen action as a string.
#
# Here is an example implementation for the agent program of a simple randomized agent:

# %%
# make sure numpy is installed
# %pip install -q numpy

# %%
import numpy as np

actions = ["north", "east", "west", "south", "suck"]

def simple_randomized_agent(bumpers, dirty):
    return np.random.choice(actions)

# %%
# define percepts (current location is NW corner and it is dirty)
bumpers = {"north" : True, "east" : False, "south" : False, "west" : True}
dirty = True

# call agent program function with percepts and it returns an action
simple_randomized_agent(bumpers, dirty)
# Out:
# np.str_('west')

# %% [markdown]
# __Note:__ This is not a rational intelligent agent. It ignores its sensors and may bump into a wall repeatedly or not clean a dirty square. You will be asked to implement rational agents below.

# %% [markdown]
# ## Simple environment example
#
# We implement a simple simulation environment that supplies the agent with its percepts.
# The simple environment is infinite in size (bumpers are always `False`) and every square is always dirty, even if the agent cleans it. The environment function returns a different performance measure than the one specified in the PEAS description! Since the room is infinite and all squares are constantly dirty, the agent can never clean the whole room. Your implementation needs to implement the **correct performance measure.** The energy budget of the agent is specified as `max_steps`.

# %%
def simple_environment_b(agent_function, max_steps, verbose = True):
    num_cleaned = 0

    for i in range(max_steps):
        dirty = True
        bumpers = {"north" : False, "south" : False, "west" : False, "east" : False}

        action = agent_function(bumpers, dirty)
        if (verbose): print("step", i , "- action:", action)

        if (action == "suck"):
            num_cleaned = num_cleaned + 1

    return num_cleaned

# %% [markdown]
# Do one simulation run with a simple randomized agent that has enough energy for 20 steps.

# %%
simple_environment(simple_randomized_agent, max_steps = 20)
# Out:
# step 0 - action: west
# step 1 - action: east
# step 2 - action: suck
# step 3 - action: south
# step 4 - action: north
# step 5 - action: north
# step 6 - action: north
# step 7 - action: west
# step 8 - action: suck
# step 9 - action: suck
# step 10 - action: east
# step 11 - action: west
# step 12 - action: south
# step 13 - action: west
# step 14 - action: south
# step 15 - action: north
# step 16 - action: south
# step 17 - action: east
# step 18 - action: north
# step 19 - action: suck
# 4

# %% [markdown]
# # Tasks
#
# ## General [10 Points]
#
# 1. Make sure that you use the latest version of this notebook.
# 2. Your implementation can use libraries like math, numpy, scipy, but not libraries that implement intelligent agents or complete search algorithms. Try to keep the code simple! In this course, we want to learn about the algorithms and we often do not need to use object-oriented design.
# 3. You notebook needs to be formatted professionally.
#     - Add additional markdown blocks for your description, comments in the code, add tables and use mathplotlib to produce charts where appropriate
#     - Do not show debugging output or include an excessive amount of output.
#     - Check that your submitted file is readable and contains all figures.
# 4. Document your code. Use comments in the code and add a discussion of how your implementation works and your design choices.
#
#
# ## Task 1: Implement a simulation environment [20 Points]
#
# The simple environment above is not very realistic. Your environment simulator needs to follow the PEAS description from above. It needs to:
#
# * Initialize the environment by storing the state of each square (clean/dirty) and making some dirty. ([Help with random numbers and arrays in Python](https://github.com/mhahsler/CS7320-AI/blob/master/HOWTOs/random_numbers_and_arrays.ipynb))
# * Keep track of the agent's position.
# * Call the agent function repeatedly and provide the agent function with the sensor inputs.
# * React to the agent's actions. E.g, by removing dirt from a square or moving the agent around unless there is a wall in the way.
# * Keep track of the performance measure. That is, track the agent's actions until all dirty squares are clean and count the number of actions it takes the agent to complete the task.
#
# The easiest implementation for the environment is to hold an 2-dimensional array to represent if squares are clean or dirty and to call the agent function in a loop until all squares are clean or a predefined number of steps have been reached (i.e., the robot runs out of energy).
#
# The simulation environment should be a function like the `simple_environment()` and needs to work with the simple randomized agent program from above. **Use the same environment for all your agent implementations in the tasks below.**
#
# *Note on debugging:* Debugging can be difficult. Here are a few options:
#
# * Make sure your environment prints enough information when you use `verbose = True`.
# * VSCode also provides a very good interactive Python debugger for notebooks. Read the [HOWTO on debugging](https://github.com/mhahsler/CS7320-AI/blob/master/HOWTOs/debugging_in_notebooks.ipynb) for more details.
# * Another very useful debugging help is to implement a function that the environment can use to displays the room with dirt and the current position of the robot at every step. You can use simple characters for dirt and the robot location.

# %%
import numpy as np
import matplotlib.pyplot as plt





def simple_environment(agent_function, n=5, dirt_probability=0.2, verbose = True, max_steps=50):
    # grid is all zeros meaning all cells are clean
    grid = np.zeros((n,n))

    # made some dirty cells
    grid[np.random.random(grid.shape) < dirt_probability] = 1

    pos = [np.random.randint(n), np.random.randint(n)]

    print(f"Starting position: {pos}, Dirty cells: {int(np.sum(grid))}")
    for step in range(max_steps):
        if np.sum(grid) == 0:
         return step

        # create bumpers to define the boundaries of the grid
        bumpers = { "north": pos[1] == n-1, "east": pos[0] == n - 1, "south": pos[1] == 0, "west": pos[0] == 0 }

        #detecting if quare is dirty
        dirty = grid[pos[0], pos[1]] ==1


        # Movment is decided if there is no wall in that direction, and distinction for current square to clean
        action = agent_function(bumpers, dirty)
        if verbose: print(f"Step {step} | Pos: {pos} | Dirty: {dirty} | Action: {action}")

        if action == "suck":
            grid[pos[0], pos[1]] = 0
        elif action == "north" and not bumpers["north"]:
            pos[1] += 1
        elif action == "south" and not bumpers["south"]:
            pos[1] -= 1
        elif action == "east" and not bumpers["east"]:
            pos[0] += 1
        elif action == "west" and not bumpers["west"]:
            pos[0] -= 1
    return max_steps

# %% [markdown]
# Show that your environment works with the simple randomized agent from above.

# %%
simple_environment(simple_randomized_agent, verbose=True)
# Out:
# Starting position: [3, 3], Dirty cells: 6
# Step 0 | Pos: [3, 3] | Dirty: True | Action: west
# Step 1 | Pos: [2, 3] | Dirty: False | Action: north
# Step 2 | Pos: [2, 4] | Dirty: False | Action: south
# Step 3 | Pos: [2, 3] | Dirty: False | Action: west
# Step 4 | Pos: [1, 3] | Dirty: False | Action: north
# Step 5 | Pos: [1, 4] | Dirty: False | Action: west
# Step 6 | Pos: [0, 4] | Dirty: True | Action: west
# Step 7 | Pos: [0, 4] | Dirty: True | Action: east
# Step 8 | Pos: [1, 4] | Dirty: False | Action: suck
# Step 9 | Pos: [1, 4] | Dirty: False | Action: east
# Step 10 | Pos: [2, 4] | Dirty: False | Action: east
# Step 11 | Pos: [3, 4] | Dirty: False | Action: south
# Step 12 | Pos: [3, 3] | Dirty: True | Action: south
# Step 13 | Pos: [3, 2] | Dirty: False | Action: suck
# Step 14 | Pos: [3, 2] | Dirty: False | Action: east
# Step 15 | Pos: [4, 2] | Dirty: False | Action: suck
# Step 16 | Pos: [4, 2] | Dirty: False | Action: west
# Step 17 | Pos: [3, 2] | Dirty: False | Action: south
# Step 18 | Pos: [3, 1] | Dirty: True | Action: east
# Step 19 | Pos: [4, 1] | Dirty: False | Action: north
# Step 20 | Pos: [4, 2] | Dirty: False | Action: west
# Step 21 | Pos: [3, 2] | Dirty: False | Action: south
# Step 22 | Pos: [3, 1] | Dirty: True | Action: north
# Step 23 | Pos: [3, 2] | Dirty: False | Action: west
# Step 24 | Pos: [2, 2] | Dirty: False | Action: south
# Step 25 | Pos: [2, 1] | Dirty: False | Action: suck
# Step 26 | Pos: [2, 1] | Dirty: False | Action: suck
# Step 27 | Pos: [2, 1] | Dirty: False | Action: south
# Step 28 | Pos: [2, 0] | Dirty: False | Action: suck
# Step 29 | Pos: [2, 0] | Dirty: False | Action: east
# Step 30 | Pos: [3, 0] | Dirty: False | Action: south
# Step 31 | Pos: [3, 0] | Dirty: False | Action: east
# Step 32 | Pos: [4, 0] | Dirty: False | Action: suck
# Step 33 | Pos: [4, 0] | Dirty: False | Action: north
# Step 34 | Pos: [4, 1] | Dirty: False | Action: east
# Step 35 | Pos: [4, 1] | Dirty: False | Action: east
# Step 36 | Pos: [4, 1] | Dirty: False | Action: west
# Step 37 | Pos: [3, 1] | Dirty: True | Action: suck
# Step 38 | Pos: [3, 1] | Dirty: False | Action: east
# Step 39 | Pos: [4, 1] | Dirty: False | Action: west
# Step 40 | Pos: [3, 1] | Dirty: False | Action: south
# Step 41 | Pos: [3, 0] | Dirty: False | Action: west
# Step 42 | Pos: [2, 0] | Dirty: False | Action: south
# Step 43 | Pos: [2, 0] | Dirty: False | Action: north
# Step 44 | Pos: [2, 1] | Dirty: False | Action: suck
# Step 45 | Pos: [2, 1] | Dirty: False | Action: east
# Step 46 | Pos: [3, 1] | Dirty: False | Action: south
# Step 47 | Pos: [3, 0] | Dirty: False | Action: suck
# Step 48 | Pos: [3, 0] | Dirty: False | Action: south
# Step 49 | Pos: [3, 0] | Dirty: False | Action: suck
# 50

# %% [markdown]
# ## Task 2:  Implement a simple reflex agent [10 Points]
#
# The simple reflex agent randomly walks around but reacts to the bumper sensor by not bumping into the wall and to dirt with sucking. Implement the agent program as a function.
#
# _Note:_ Agents cannot directly use variable in the environment. They only gets the percepts as the arguments to the agent function. Use the function signature for the `simple_randomized_agent` function above.

# %%
def simple_reflex_agent(bumpers, dirty):
    if dirty:
        return "suck"

    # build list of directions that aren't blocked
    available_moves = []
    for direction in ["north", "south", "east", "west"]:
        if not bumpers[direction]:
            available_moves.append(direction)

    return np.random.choice(available_moves)

# %% [markdown]
# Show how the agent works with your environment.

# %%
simple_environment(simple_reflex_agent, verbose=True)
# Out:
# Starting position: [4, 4], Dirty cells: 3
# Step 0 | Pos: [4, 4] | Dirty: True | Action: suck
# Step 1 | Pos: [4, 4] | Dirty: False | Action: south
# Step 2 | Pos: [4, 3] | Dirty: True | Action: suck
# Step 3 | Pos: [4, 3] | Dirty: False | Action: north
# Step 4 | Pos: [4, 4] | Dirty: False | Action: south
# Step 5 | Pos: [4, 3] | Dirty: False | Action: west
# Step 6 | Pos: [3, 3] | Dirty: False | Action: west
# Step 7 | Pos: [2, 3] | Dirty: False | Action: south
# Step 8 | Pos: [2, 2] | Dirty: False | Action: east
# Step 9 | Pos: [3, 2] | Dirty: False | Action: west
# Step 10 | Pos: [2, 2] | Dirty: False | Action: west
# Step 11 | Pos: [1, 2] | Dirty: False | Action: west
# Step 12 | Pos: [0, 2] | Dirty: False | Action: north
# Step 13 | Pos: [0, 3] | Dirty: False | Action: east
# Step 14 | Pos: [1, 3] | Dirty: False | Action: north
# Step 15 | Pos: [1, 4] | Dirty: False | Action: east
# Step 16 | Pos: [2, 4] | Dirty: False | Action: west
# Step 17 | Pos: [1, 4] | Dirty: False | Action: east
# Step 18 | Pos: [2, 4] | Dirty: False | Action: west
# Step 19 | Pos: [1, 4] | Dirty: False | Action: east
# Step 20 | Pos: [2, 4] | Dirty: False | Action: west
# Step 21 | Pos: [1, 4] | Dirty: False | Action: south
# Step 22 | Pos: [1, 3] | Dirty: False | Action: east
# Step 23 | Pos: [2, 3] | Dirty: False | Action: east
# Step 24 | Pos: [3, 3] | Dirty: False | Action: east
# Step 25 | Pos: [4, 3] | Dirty: False | Action: south
# Step 26 | Pos: [4, 2] | Dirty: False | Action: south
# Step 27 | Pos: [4, 1] | Dirty: False | Action: north
# Step 28 | Pos: [4, 2] | Dirty: False | Action: west
# Step 29 | Pos: [3, 2] | Dirty: False | Action: east
# Step 30 | Pos: [4, 2] | Dirty: False | Action: west
# Step 31 | Pos: [3, 2] | Dirty: False | Action: south
# Step 32 | Pos: [3, 1] | Dirty: False | Action: west
# Step 33 | Pos: [2, 1] | Dirty: False | Action: east
# Step 34 | Pos: [3, 1] | Dirty: False | Action: west
# Step 35 | Pos: [2, 1] | Dirty: False | Action: south
# Step 36 | Pos: [2, 0] | Dirty: False | Action: east
# Step 37 | Pos: [3, 0] | Dirty: False | Action: east
# Step 38 | Pos: [4, 0] | Dirty: False | Action: west
# Step 39 | Pos: [3, 0] | Dirty: False | Action: east
# Step 40 | Pos: [4, 0] | Dirty: False | Action: north
# Step 41 | Pos: [4, 1] | Dirty: False | Action: west
# Step 42 | Pos: [3, 1] | Dirty: False | Action: south
# Step 43 | Pos: [3, 0] | Dirty: False | Action: east
# Step 44 | Pos: [4, 0] | Dirty: False | Action: west
# Step 45 | Pos: [3, 0] | Dirty: False | Action: east
# Step 46 | Pos: [4, 0] | Dirty: False | Action: north
# Step 47 | Pos: [4, 1] | Dirty: False | Action: west
# Step 48 | Pos: [3, 1] | Dirty: False | Action: north
# Step 49 | Pos: [3, 2] | Dirty: False | Action: south
# 50

# %% [markdown]
# ## Task 3: Implement a model-based reflex agent [20 Points]
#
# Model-based agents use a state to keep track of what they have done and perceived so far. Your agent needs to find out where it is located and then keep track of its current location. You also need a set of rules based on the state and the percepts to make sure that the agent will clean the whole room. For example, the agent can move to a corner to determine its location and then it can navigate through the whole room and clean dirty squares.
#
# Describe how you define the __agent state__ and how your agent works before implementing it. ([Help with implementing state information in Python](https://github.com/mhahsler/CS7320-AI/blob/master/HOWTOs/store_agent_state_information.ipynb))

# %%
# My Model-Based Reflex Agent- lawn mower implimentation
#For agent state, i have two variables which i am keeping track of to see whats happening:
# 1. This is the "phase": this is telling the agent what its currently doing
#     A. " go_south" : first this moves the agent all the way to the bottom
#     B. " go_west" : goes all the way to the left
#     C. " Sweep" : This cleans row by row
#
# 2. Direction- This is a tab that remembers if its going left or right
# For the agent state, I'm using two main variables to keep track of what's happening:
#
# Logic:
# 1. First suck if dirty
# 2. move it to 0,0 since we dont know where the agent is
# 3. once there lawn mower strategy make sure to hit as many boxes as possible to find dirt

# %%
class ModelBasedReflexAgent:
    def __init__(self):
        self.phase = "go_south"
        self.direction = "east"

    def act(self, bumpers, dirty):
        if dirty:
            return "suck"

        #all the way south first
        if self.phase == "go_south" :
            if not bumpers["south"]:
                return "south"
            self.phase = "go_west"

        #next go all the way east
        if self.phase == "go_west":
            if not bumpers["west"]:
                return "west"
            self.phase = "sweep"

        #step 3 sweep east and west and move north when agent hits the wall
        if self.phase == "sweep":
            if not bumpers[self.direction]:
                return self.direction
            if not bumpers["north"]:
                self.direction = "west" if self.direction == "east" else "east"
                return "north"

        return "suck"

# %% [markdown]
# Show how the agent works with your environment.

# %%
agent = ModelBasedReflexAgent()
simple_environment(agent.act, verbose=True)
# Out:
# Starting position: [0, 1], Dirty cells: 5
# Step 0 | Pos: [0, 1] | Dirty: True | Action: suck
# Step 1 | Pos: [0, 1] | Dirty: False | Action: south
# Step 2 | Pos: [0, 0] | Dirty: False | Action: east
# Step 3 | Pos: [1, 0] | Dirty: False | Action: east
# Step 4 | Pos: [2, 0] | Dirty: True | Action: suck
# Step 5 | Pos: [2, 0] | Dirty: False | Action: east
# Step 6 | Pos: [3, 0] | Dirty: False | Action: east
# Step 7 | Pos: [4, 0] | Dirty: False | Action: north
# Step 8 | Pos: [4, 1] | Dirty: False | Action: west
# Step 9 | Pos: [3, 1] | Dirty: True | Action: suck
# Step 10 | Pos: [3, 1] | Dirty: False | Action: west
# Step 11 | Pos: [2, 1] | Dirty: False | Action: west
# Step 12 | Pos: [1, 1] | Dirty: False | Action: west
# Step 13 | Pos: [0, 1] | Dirty: False | Action: north
# Step 14 | Pos: [0, 2] | Dirty: False | Action: east
# Step 15 | Pos: [1, 2] | Dirty: False | Action: east
# Step 16 | Pos: [2, 2] | Dirty: True | Action: suck
# Step 17 | Pos: [2, 2] | Dirty: False | Action: east
# Step 18 | Pos: [3, 2] | Dirty: False | Action: east
# Step 19 | Pos: [4, 2] | Dirty: False | Action: north
# Step 20 | Pos: [4, 3] | Dirty: False | Action: west
# Step 21 | Pos: [3, 3] | Dirty: True | Action: suck
# 22

# %% [markdown]
# ## Task 4: Simulation study [30 Points]
#
# Compare the performance (the performance measure is defined in the PEAS description above) of the agents using  environments of different size. Do at least $5 \times 5$, $10 \times 10$ and
# $100 \times 100$. Use 100 random runs for each. Present the results using tables and graphs. Discuss the differences between the agents.
# ([Help with charts and tables in Python](https://github.com/mhahsler/CS7320-AI/blob/master/HOWTOs/charts_and_tables.ipynb))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

grid_sizes = [5, 10, 100]
num_runs = 100
max_steps = 50000

# store results in a dictionary like the HOWTO
performance = {}

for n in grid_sizes:
    performance[f"{n}x{n}"] = {
        "Simple Randomized": [],
        "Simple Reflex": [],
        "Model-Based Reflex": []
    }

    for run in range(num_runs):
        performance[f"{n}x{n}"]["Simple Randomized"].append(
            simple_environment(simple_randomized_agent, n=n, max_steps=max_steps, verbose=False))

        performance[f"{n}x{n}"]["Simple Reflex"].append(
            simple_environment(simple_reflex_agent, n=n, max_steps=max_steps, verbose=False))

        agent = ModelBasedReflexAgent()
        performance[f"{n}x{n}"]["Model-Based Reflex"].append(
            simple_environment(agent.act, n=n, max_steps=max_steps, verbose=False))
# Out:
# Starting position: [0, 0], Dirty cells: 6
# Starting position: [1, 4], Dirty cells: 6
# Starting position: [0, 0], Dirty cells: 8
# Starting position: [3, 4], Dirty cells: 5
# Starting position: [4, 3], Dirty cells: 4
# Starting position: [1, 2], Dirty cells: 5
# Starting position: [2, 2], Dirty cells: 4
# Starting position: [4, 3], Dirty cells: 6
# Starting position: [0, 1], Dirty cells: 4
# Starting position: [4, 1], Dirty cells: 10
# Starting position: [0, 1], Dirty cells: 2
# Starting position: [4, 4], Dirty cells: 4
# Starting position: [3, 0], Dirty cells: 8
# Starting position: [0, 1], Dirty cells: 5
# Starting position: [4, 1], Dirty cells: 5
# Starting position: [4, 0], Dirty cells: 8
# Starting position: [2, 0], Dirty cells: 3
# Starting position: [3, 2], Dirty cells: 3
# Starting position: [2, 0], Dirty cells: 4
# Starting position: [0, 4], Dirty cells: 6
# Starting position: [4, 4], Dirty cells: 6
# Starting position: [1, 1], Dirty cells: 7
# Starting position: [0, 4], Dirty cells: 7
# Starting position: [0, 2], Dirty cells: 4
# Starting position: [1, 4], Dirty cells: 5
# Starting position: [4, 2], Dirty cells: 6
# Starting position: [2, 1], Dirty cells: 5
# Starting position: [3, 2], Dirty cells: 4
# Starting position: [2, 4], Dirty cells: 6
# Starting position: [4, 2], Dirty cells: 6
# Starting position: [0, 0], Dirty cells: 10
# Starting position: [0, 3], Dirty cells: 8
# Starting position: [4, 4], Dirty cells: 4
# Starting position: [2, 3], Dirty cells: 5
# Starting position: [1, 3], Dirty cells: 6
# Starting position: [3, 4], Dirty cells: 6
# Starting position: [2, 0], Dirty cells: 4
# Starting position: [3, 4], Dirty cells: 5
# Starting position: [1, 1], Dirty cells: 8
# Starting position: [4, 4], Dirty cells: 3
# Starting position: [3, 2], Dirty cells: 4
# Starting position: [1, 0], Dirty cells: 2
# Starting position: [1, 0], Dirty cells: 5
# Starting position: [3, 3], Dirty cells: 8
# Starting position: [1, 0], Dirty cells: 3
# Starting position: [3, 2], Dirty cells: 4
# Starting position: [3, 0], Dirty cells: 4
# Starting position: [0, 2], Dirty cells: 8
# Starting position: [4, 0], Dirty cells: 7
# Starting position: [4, 3], Dirty cells: 4
# Starting position: [4, 4], Dirty cells: 8
# Starting position: [2, 1], Dirty cells: 8
# Starting position: [2, 2], Dirty cells: 3
# Starting position: [2, 0], Dirty cells: 4
# Starting position: [4, 4], Dirty cells: 7
# Starting position: [2, 4], Dirty cells: 3
# Starting position: [3, 2], Dirty cells: 6
# Starting position: [1, 3], Dirty cells: 2
# Starting position: [0, 4], Dirty cells: 7
# Starting position: [0, 1], Dirty cells: 7
# Starting position: [0, 3], Dirty cells: 7
# Starting position: [1, 0], Dirty cells: 2
# Starting position: [1, 0], Dirty cells: 4
# Starting position: [0, 1], Dirty cells: 2
# Starting position: [2, 0], Dirty cells: 3
# Starting position: [3, 2], Dirty cells: 6
# Starting position: [1, 1], Dirty cells: 4
# Starting position: [3, 2], Dirty cells: 1
# Starting position: [3, 4], Dirty cells: 4
# Starting position: [4, 2], Dirty cells: 6
# Starting position: [1, 0], Dirty cells: 10
# Starting position: [3, 2], Dirty cells: 8
# Starting position: [3, 3], Dirty cells: 6
# Starting position: [1, 2], Dirty cells: 3
# Starting position: [0, 4], Dirty cells: 3
# Starting position: [0, 1], Dirty cells: 5
# Starting position: [1, 0], Dirty cells: 6
# Starting position: [0, 3], Dirty cells: 7
# Starting position: [0, 2], Dirty cells: 8
# Starting position: [0, 3], Dirty cells: 6
# Starting position: [0, 4], Dirty cells: 5
# Starting position: [0, 0], Dirty cells: 2
# Starting position: [0, 0], Dirty cells: 6
# Starting position: [3, 3], Dirty cells: 5
# Starting position: [0, 4], Dirty cells: 4
# Starting position: [3, 3], Dirty cells: 9
# Starting position: [1, 2], Dirty cells: 6
# Starting position: [4, 1], Dirty cells: 4
# Starting position: [3, 4], Dirty cells: 3
# Starting position: [4, 1], Dirty cells: 6
# Starting position: [3, 2], Dirty cells: 4
# Starting position: [4, 2], Dirty cells: 6
# Starting position: [3, 3], Dirty cells: 8
# Starting position: [1, 2], Dirty cells: 7
# Starting position: [1, 2], Dirty cells: 6
# Starting position: [3, 0], Dirty cells: 5
# Starting position: [1, 4], Dirty cells: 8
# Starting position: [0, 3], Dirty cells: 5
# Starting position: [0, 4], Dirty cells: 2
# Starting position: [3, 2], Dirty cells: 5
# Starting position: [2, 1], Dirty cells: 8
# Starting position: [1, 2], Dirty cells: 8
# Starting position: [1, 2], Dirty cells: 5
# Starting position: [0, 0], Dirty cells: 6
# Starting position: [4, 4], Dirty cells: 3
# Starting position: [0, 4], Dirty cells: 8
# Starting position: [0, 3], Dirty cells: 3
# Starting position: [0, 4], Dirty cells: 5
# Starting position: [0, 2], Dirty cells: 8
# Starting position: [4, 1], Dirty cells: 4
# Starting position: [2, 3], Dirty cells: 11
# Starting position: [4, 3], Dirty cells: 4
# Starting position: [2, 3], Dirty cells: 6
# Starting position: [1, 2], Dirty cells: 5
# Starting position: [4, 2], Dirty cells: 5
# Starting position: [2, 2], Dirty cells: 5
# Starting position: [4, 1], Dirty cells: 3
# Starting position: [3, 1], Dirty cells: 9
# Starting position: [4, 3], Dirty cells: 7
# Starting position: [81, 24], Dirty cells: 1965
# Starting position: [99, 39], Dirty cells: 2009
# Starting position: [46, 85], Dirty cells: 2050
# Starting position: [14, 16], Dirty cells: 2016
# Starting position: [32, 74], Dirty cells: 1969
# Starting position: [84, 92], Dirty cells: 1985
# Starting position: [67, 68], Dirty cells: 1971
# Starting position: [8, 88], Dirty cells: 1975
# Starting position: [91, 53], Dirty cells: 1979
# Starting position: [82, 61], Dirty cells: 2059
# Starting position: [75, 67], Dirty cells: 1946
# Starting position: [80, 83], Dirty cells: 2008
# Starting position: [38, 56], Dirty cells: 2068
# Starting position: [48, 12], Dirty cells: 1938
# Starting position: [39, 73], Dirty cells: 1996
# Starting position: [33, 61], Dirty cells: 1967
# Starting position: [83, 71], Dirty cells: 1971
# Starting position: [88, 22], Dirty cells: 2011
# Starting position: [80, 35], Dirty cells: 2041

# %% [markdown]
# Fill out the following table with the average performance measure for 100 random runs (you may also create this table with code):
#
# | Size     | Randomized Agent | Simple Reflex Agent | Model-based Reflex Agent |
# |----------|------------------|---------------------|--------------------------|
# | 5x5     | | | |
# | 10x10   | | | |
# | 100x100 | | | |
#
# Add charts to compare the performance of the different agents.

# %%
# Your graphs and discussion of the results goes here

# %% [markdown]
# ## Task 5: Robustness of the agent implementations [10 Points]
#
# Describe how **your agent implementations** will perform
#
# * if it is put into a rectangular room with unknown size,
# * if the cleaning area can have an irregular shape (e.g., a hallway connecting two rooms), or
# * if the room contains obstacles (i.e., squares that it cannot pass through and trigger the bumper sensors).
# * if the dirt sensor is not perfect and gives 10% of the time a wrong reading (clean when it is dirty or dirty when it is clean).
# * if the bumper sensor is not perfect and 10% of the time does not report a wall when there is one.

# %%
# Answers goes here

# %% [markdown]
# ## Advanced task: Imperfect Dirt Sensor
#
# * __Graduate students__ need to complete this task [10 points]
# * __Undergraduate students__ can attempt this as a bonus task [max +5 bonus points].
#
# 1. Change your simulation environment to run experiments for the following problem: The dirt sensor has a 10% chance of giving the wrong reading. Perform experiments to observe how this changes the performance of the three implementations. Your model-based reflex agent is likely not able to clean the whole room, so you need to measure performance differently as a tradeoff between energy cost and number of uncleaned squares.
#
# 2. Design an implement a solution for your model-based agent that will clean better. Show the improvement with experiments.

# %%
# Your code and discussion goes here

# %% [markdown]
# ## More Advanced Implementation (not for credit)
#
# If the assignment was to easy for you then you can think about the following problems. These problems are challenging and not part of this assignment. We will learn implementation strategies and algorithms useful for these tasks during the rest of the semester.
#
# * __Obstacles:__ Change your simulation environment to run experiments for the following problem: Add random obstacle squares that also trigger the bumper sensor. The agent does not know where the obstacles are. Perform experiments to observe how this changes the performance of the three implementations. Describe what would need to be done to perform better with obstacles. Add code if you can.
#
# * __Agent for and environment with obstacles:__ Implement an agent for an environment where the agent does not know how large the environment is (we assume it is rectangular), where it starts or where the obstacles are. An option would be to always move to the closest unchecked/uncleaned square (note that this is actually depth-first search).
#
# * __Utility-based agent:__ Change the environment for a $5 \times 5$ room, so each square has a fixed probability of getting dirty again. For the implementation, we give the environment a 2-dimensional array of probabilities. The utility of a state is defined as the number of currently clean squares in the room. Implement a utility-based agent that maximizes the expected utility over one full charge which lasts for 100000 time steps. To do this, the agent needs to learn the probabilities with which different squares get dirty again. This is very tricky!

# %%
# Your ideas/code

# %% [markdown]
# &copy; 2025 [Michael Hahsler](http://michael.hahsler.net).
# This work is openly licensed under [Creative Commons Attribution-ShareAlike 4.0 International (CC BY-SA 4.0) License](https://creativecommons.org/licenses/by-sa/4.0/)
#
# ![CC BY-SA 4.0](https://licensebuttons.net/l/by-sa/3.0/88x31.png)
